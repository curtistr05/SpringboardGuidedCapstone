# %% [markdown]
# # Guided Capstone Step 3 Exploratory Data Analysis

# %% [markdown]
# This is the third step in the Data Science Method. We introduced this topic in the last subunit. With Data Wrangling out of the way we can progress to the Exploratory Data Analysis section. In this exercise, you will learn to build data profiles and plots, including relationship plot and data correlation plot. You will also implement k-means clustering, complete clusters, and update data frame as a CSV file. Let's get started!
#
# **The Data Science Method**
#
#
# 1.   Problem Identification
#
# 2.   Data Wrangling
#   * Data Collection
#    * Data Organization
#   * Data Definition
#   * Data Cleaning
#
# 3.   **Exploratory Data Analysis**
#  * Build data profile tables and plots
#         - Outliers & Anomalies
#  * Explore data relationships
#  * Identification and creation of features
#
# 4.   Pre-processing and Training Data Development
#   * Create dummy or indicator features for categorical variables
#   * Standardize the magnitude of numeric features
#   * Split into testing and training datasets
#   * Apply scaler to the testing set
# 5.   Modeling
#   * Fit Models with Training Data Set
#   * Review Model Outcomes — Iterate over additional models as needed.
#   * Identify the Final Model
#
# 6.   Documentation
#   * Review the Results
#   * Present and share your findings - storytelling
#   * Finalize Code
#   * Finalize Documentation

# %% [markdown]
# **<font color='teal'> Start by loading the necessary packages as we did in step 2 and printing out our current working directory just to confirm we are in the correct project directory. </font>**

# %%
#load python packages
import os
import pandas as pd
import datetime
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %% [markdown]
# **<font color='teal'> If you need to change your path refer back to step 2 on how to do that. Then load the csv file you created in step 2, remember it should be saved inside your data subfolder and print the first five rows.</font>**

# %%
step2_output = pd.read_csv(r"C:/Users/Curtis/Documents/SpringboardGuidedCapstone/data/step2_output.csv")
step2_output.head()
# Out:
#                   Name   Region    state  summit_elev  vertical_drop  \
# 0       Alyeska Resort   Alaska   Alaska         3939           2500
# 1  Eaglecrest Ski Area   Alaska   Alaska         2600           1540
# 2     Hilltop Ski Area   Alaska   Alaska         2090            294
# 3     Arizona Snowbowl  Arizona  Arizona        11500           2300
# 4  Sunrise Park Resort  Arizona  Arizona        11100           1800
#
#    base_elev  trams  fastEight  fastSixes  fastQuads  ...  LongestRun_mi  \
# 0        250      1          0          0          2  ...              1
# 1       1200      0          0          0          0  ...              2
# 2       1796      0          0          0          0  ...              1
# 3       9200      0          0          1          0  ...              2
# 4       9200      0          0          0          1  ...              1
#
#    SkiableTerrain_ac  Snow Making_ac  daysOpenLastYear  yearsOpen  \
# 0               1610             113               150         60
# 1                640              60                45         44
# 2                 30              30               150         36
# 3                777             104               122         81
# 4                800              80               115         49
#
#    averageSnowfall  AdultWeekday  AdultWeekend  projectedDaysOpen  \
# 0              669            65            85                150
# 1              350            47            53                 90
# 2               69            30            34                152
# 3              260            89            89                122
# 4              250            74            78                104
#
#    NightSkiing_ac
# 0             550
# 1               0
# 2              30
# 3               0
# 4              80
#
# [5 rows x 27 columns]

# %% [markdown]
# # Build data profile tables and plots

# %% [markdown]
# **<font color='teal'> Print out the summary stats table transposed to fit on the screen using the `describe()` function.</font>**

# %%
step2_output.describe()
# Out:
#         summit_elev  vertical_drop     base_elev       trams   fastEight  \
# count    330.000000     330.000000    330.000000  330.000000  330.000000
# mean    4591.818182    1215.427273   3374.000000    0.172727    0.003030
# std     3735.535934     947.864557   3117.121621    0.559946    0.055048
# min      315.000000      60.000000     70.000000    0.000000    0.000000
# 25%     1403.750000     461.250000    869.000000    0.000000    0.000000
# 50%     3127.500000     964.500000   1561.500000    0.000000    0.000000
# 75%     7806.000000    1800.000000   6325.250000    0.000000    0.000000
# max    13487.000000    4425.000000  10800.000000    4.000000    1.000000
#
#         fastSixes   fastQuads        quad     triple      double  ...  \
# count  330.000000  330.000000  330.000000  330.00000  330.000000  ...
# mean     0.184848    1.018182    0.933333    1.50000    1.833333  ...
# std      0.651685    2.198294    1.312245    1.61913    1.815028  ...
# min      0.000000    0.000000    0.000000    0.00000    0.000000  ...
# 25%      0.000000    0.000000    0.000000    0.00000    1.000000  ...
# 50%      0.000000    0.000000    0.000000    1.00000    1.000000  ...
# 75%      0.000000    1.000000    1.000000    2.00000    3.000000  ...
# max      6.000000   15.000000    8.000000    8.00000   14.000000  ...
#
#        LongestRun_mi  SkiableTerrain_ac  Snow Making_ac  daysOpenLastYear  \
# count     330.000000         330.000000      330.000000        330.000000
# mean        1.139394         739.793939      174.751515        115.087879
# std         1.194704        1807.868081      242.379037         32.231234
# min         0.000000           8.000000        2.000000          3.000000
# 25%         0.000000          85.000000       55.000000        100.000000
# 50%         1.000000         200.000000      132.500000        115.000000
# 75%         2.000000         739.000000      192.000000        130.000000
# max         6.000000       26819.000000     3379.000000        305.000000
#
#          yearsOpen  averageSnowfall  AdultWeekday  AdultWeekend  \
# count   330.000000        330.00000    330.000000    330.000000
# mean     63.654545        185.30303     57.760606     64.136364
# std     109.263500        133.42411     23.899873     22.570717
# min       6.000000         18.00000     15.000000     17.000000
# 25%      50.000000         71.25000     43.000000     49.000000
# 50%      58.000000        158.00000     57.000000     64.000000
# 75%      68.750000        278.75000     67.000000     72.000000
# max    2019.000000        669.00000    179.000000    179.000000
#
#        projectedDaysOpen  NightSkiing_ac
# count         330.000000      330.000000
# mean          120.045455       56.890909
# std            28.742982       93.464882
# min            30.000000        0.000000
# 25%           101.250000        0.000000
# 50%           120.000000       27.000000
# 75%           136.000000       83.750000
# max           305.000000      650.000000
#
# [8 rows x 24 columns]

# %% [markdown]
# **<font color='teal'> Histograms are an excellent way to review the range and density of values for each numeric features in your data set and build data profiles. Plot the histograms for all numeric features and adjust the bins size to 25.</font>**

# %%
step2_output['summit_elev'].plot.hist(bins=25)
plt.xlabel('Summit Elevation')
# Out:
# Text(0.5, 0, 'Summit Elevation')

# %%
step2_output['vertical_drop'].plot.hist(bins=25)
plt.xlabel('Vertical Drop')
# Out:
# Text(0.5, 0, 'Vertical Drop')

# %%
step2_output['total_chairs'].plot.hist(bins=25)
plt.xlabel('Total Chair Lifts')
# Out:
# Text(0.5, 0, 'Total Chair Lifts')

# %%
step2_output['Runs'].plot.hist(bins=25)
plt.xlabel('Total Runs')
# Out:
# Text(0.5, 0, 'Total Runs')

# %%
step2_output['SkiableTerrain_ac'].plot.hist(bins=25)
plt.xlabel('Skiable Terrain ac')
# Out:
# Text(0.5, 0, 'Skiable Terrain ac')

# %%
step2_output['Snow Making_ac'].plot.hist(bins=25)
plt.xlabel('Snow Making ac')
# Out:
# Text(0.5, 0, 'Snow Making ac')

# %%
step2_output['daysOpenLastYear'].plot.hist(bins=25)
plt.xlabel('Days Open Last Year')
# Out:
# Text(0.5, 0, 'Days Open Last Year')

# %%
step2_output['NightSkiing_ac'].plot.hist(bins=25)
plt.xlabel('Night Skiing ac')
# Out:
# Text(0.5, 0, 'Night Skiing ac')

# %% [markdown]
# Look for similarities in the features that may indicate that they are duplicates or highly correlated features. Make a note of your findings and any other interesting insights you find about these numeric features.

# %% [markdown]
# **<font color='teal'> Okay, now you should be getting a sense for what the data look like. Let's create a barplot for the categorical features `Region` and `state` where the heights of the bars are the counts of each level in that variable. </font>**

# %% [markdown]
# **<font color='teal'>State Levels Plot</font>**

# %%
# Uncomment the following code to get your visualization started 
f, ax = plt.subplots(figsize=(10, 10))

# In the following brackets, we want the value_counts() of the states 
x = pd.DataFrame(step2_output.state.value_counts())

# Get the state names by calling list() on the x.index
names = list(x.index)

# Get the values by plugging x.state into the list() function
values = list(x.state)

# We're now going to call the barplot() method on our sns seaborn object. 
# If you don't have a searborn object yet, make sure you've imported seaborn as sns in your imports above. 
sns.barplot(x=values, y=names, palette="RdBu_r")

# %% [markdown]
# **<font color='teal'>Region Levels Plot</font>**

# %%
# Now do the same for regions! 
f, ax = plt.subplots(figsize=(10, 10))

# In the following brackets, we want the value_counts() of the states 
x = pd.DataFrame(step2_output.Region.value_counts())

# Get the state names by calling list() on the x.index
names = list(x.index)

# Get the values by plugging x.state into the list() function
values = list(x.Region)

# We're now going to call the barplot() method on our sns seaborn object. 
# If you don't have a searborn object yet, make sure you've imported seaborn as sns in your imports above. 
sns.barplot(x=values, y=names, palette="RdBu_r")

# %% [markdown]
# By reviewing the State and Regions counts plots you should notice that the Region feature is nearly identical to the state and therfore we can remove from the dataframe.**<font color='teal'> Remove the `Region` column using the drop function.</font>**

# %%
step2_output = step2_output.drop(step2_output.columns[1], axis=1)
step2_output.head()
# Out:
#                   Name    state  summit_elev  vertical_drop  base_elev  trams  \
# 0       Alyeska Resort   Alaska         3939           2500        250      1
# 1  Eaglecrest Ski Area   Alaska         2600           1540       1200      0
# 2     Hilltop Ski Area   Alaska         2090            294       1796      0
# 3     Arizona Snowbowl  Arizona        11500           2300       9200      0
# 4  Sunrise Park Resort  Arizona        11100           1800       9200      0
#
#    fastEight  fastSixes  fastQuads  quad  ...  LongestRun_mi  \
# 0          0          0          2     2  ...              1
# 1          0          0          0     0  ...              2
# 2          0          0          0     0  ...              1
# 3          0          1          0     2  ...              2
# 4          0          0          1     2  ...              1
#
#    SkiableTerrain_ac  Snow Making_ac  daysOpenLastYear  yearsOpen  \
# 0               1610             113               150         60
# 1                640              60                45         44
# 2                 30              30               150         36
# 3                777             104               122         81
# 4                800              80               115         49
#
#    averageSnowfall  AdultWeekday  AdultWeekend  projectedDaysOpen  \
# 0              669            65            85                150
# 1              350            47            53                 90
# 2               69            30            34                152
# 3              260            89            89                122
# 4              250            74            78                104
#
#    NightSkiing_ac
# 0             550
# 1               0
# 2              30
# 3               0
# 4              80
#
# [5 rows x 26 columns]

# %% [markdown]
# ## Anamolies & Outliers - Review boxplots

# %% [markdown]
# **<font color='teal'> Print boxplot for every column</font>**
#
# Hint: you'll see the methodology here in this article on Exploratory Data Analysis [here](nce-method-dsm-exploratory-data-analysis-bc84d4d8d3f9).

# %%
boxplot = step2_output.boxplot(grid=False, vert=False, fontsize=15, color='teal', figsize=(12,15))

# %% [markdown]
# You need to create boxplots and  histograms to evaluate the data for potential outliers or data anomalies. Generally, outliers are defined as observations that differ significantly from the other values in the dataset or feature.
#
# Reviewing the distribution of values by column will help you  interpret this. Outliers are extreme values that fall far outside the mean and standard deviation of a set of observations. They  can mislead the training process in building machine learning models. Outliers may be real anomalies in the observations or artificial errors.
#
# One method for outlier analysis is extreme value analysis using a boxplot, which assumes a normal distribution. The figure below describes the components of a boxplot. Notice the outlier is the point outside the upper whisker end.
#
# ![](AnnotatedBoxplot.png)
# <font color='teal'>Follow these steps:
#
# 1. Create boxplots - earlier step
# 2. Apply outlier removal using the Interquartile range or replacement
# 3. Review how many observations were removed</font>
#
# Hint: Recall from your statistics prework that a common definition of an outlier is an observation lying more than (1.5 * the Interquartile range) above the third quartile, or more than just that much below the first quartile.

# %%
# Let's get the Interquartile range, or IQR. This is equal to Q3 - Q1. 
# First, let's use the quantile() method to get the first quartile, and store it in a variable called Q1.
# We'll want to plug 0.25 into the quantile method. 
Q1 = step2_output.quantile(0.25)

# Now get Q3 and store in a variable called Q3. 
Q3 = step2_output.quantile(0.75)
# Now calculate the IQR, storing it in a variable called IQR.
IQR = Q3 - Q1
# Make a variable called `dfno`, and assign it the value: df[~((df < (Q1 - 1.5 * IQR)) |(df> (Q3 + 1.5 * IQR))).any(axis=1)]. 
# This filters on our existing dataframe, picking out just those observations that are NOT outliers. 
dfno = step3_output[~((step3_output < (Q1 - 1.5 * IQR)) | (step3_output > (Q3 + 1.5 * IQR))).any(axis=1)]
# We now want to make a boxplot of this new dataframe dfno. 
newboxplot = dfno.boxplot(grid=False, vert=False,fontsize=15, figsize=(12,15))

# %%
# Print the shapes of our dataframes df and dfno to compare the number of observations in each. 
step2_output.shape
# Out:
# (330, 26)

# %%
dfno.shape
# Out:
# (176, 26)

# %% [markdown]
# There are many ways to discover and remove outliers, and what counts as a sensible way of doing so depends on your problem, your methodology for solving that problem, and the nature of your data.
#
# Each method will have its merits and demerits. As we can see, in this instance, we've lost a great many observations!
#
# There is no hard and fast rule as to which outlier removal method is best in all cases, and you will have to exercise your good judgement in arriving at an appropriate method for your problem at hand. We will cover outlier removal in more depth in units 7 (Data Wrangling) and 10 (Statistics for Exploratory Data Analysis) of the course.

# %% [markdown]
# There are many possible response variables you could have identified in Step 1 of this guided capstone. However, for the rest of this guided capstone project, we will focus on increasing revenue by increasing the lift ticket prices and the number of days the resort is open per year. In this case, we need to investigate the expected lift ticket price for Big Mountain based on all the other given resort characteristics. In addition, we want to predict the number of days the resort will be open each season.

# %% [markdown]
# <font color='teal'>**Review the `AdultWeekday`,`AdultWeekend` response variable distributions**</font>

# %%
# Make a histogram of the 'AdultWeekday' column of the dfno dataframe. 
# You'll want to call hist() on that column 
dfno['AdultWeekday'].plot.hist(bins=25)
plt.xlabel('AdultWeekday')
# Out:
# Text(0.5, 0, 'AdultWeekday')

# %%
# Do the same but with the AdultWeekend column 
dfno['AdultWeekend'].plot.hist(bins=25)
plt.xlabel('AdultWeekend')
# Out:
# Text(0.5, 0, 'AdultWeekend')

# %% [markdown]
# <font color='teal'>**Review the `daysOpenLastYear`,`projecteDaysOpen` response variable distributions**</font>

# %%
# Do the same as above! You got this :) 
dfno['daysOpenLastYear'].plot.hist(bins=25)
plt.xlabel('daysOpenLastYear')
# Out:
# Text(0.5, 0, 'daysOpenLastYear')

# %%
dfno['projectedDaysOpen'].plot.hist(bins=25)
plt.xlabel('projectedDaysOpen')
# Out:
# Text(0.5, 0, 'projectedDaysOpen')

# %% [markdown]
# After reviewing these respons varible distributions, there doesn't appear to be any data issues to mitigate. Now, we move on to investigating feature relationship and interactions between the features the response.

# %% [markdown]
# # Explore data relationships

# %% [markdown]
# <font color='teal'>**Create pairplots or what is commonly referred to as biplots**</font>
#
# Hint: pairplots are covered in this article on EDA [here](https://medium.com/@aiden.dataminer/the-data-science-method-dsm-exploratory-data-analysis-bc84d4d8d3f9).

# %%
pairplotdata = dfno.loc[:, ['projectedDaysOpen', 'daysOpenLastYear', 'AdultWeekday', 'AdultWeekend' ]]
ppd = sns.PairGrid(pairplotdata)
ppd.map(plt.scatter);

# %% [markdown]
# # Identification and creation of features

# %% [markdown]
# <font color='teal'>**Create a Pearson correlation heatmap**</font>

# %%
#Calculate the correlation coefficients
corr = dfno.corr()
#plot it in the next line
corr.round(2).style.background_gradient(cmap='coolwarm')
# Out:
# C:\Users\Curtis\anaconda3\lib\site-packages\matplotlib\colors.py:527: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# C:\Users\Curtis\anaconda3\lib\site-packages\pandas\io\formats\style.py:1089: RuntimeWarning: All-NaN slice encountered
#   smin = np.nanmin(s.to_numpy()) if vmin is None else vmin
# C:\Users\Curtis\anaconda3\lib\site-packages\pandas\io\formats\style.py:1090: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax(s.to_numpy()) if vmax is None else vmax
# <style  type="text/css" >
#     #T_ff3704e8_8cb6_11ea_81f9_e03f49dd8211row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_ff3704e8_8cb6_11ea_81f9_e03f49dd8211row0_col1 {
#             background-color:  #f7a688;
#             color:  #000000;
#         }    #T_ff3704e8_8cb6_11ea_81f9_e03f49dd8211row0_col2 {
#             background-color:  #b50927;
#             color:  #f1f1f1;
#         }    #T_ff3704e8_8cb6_11ea_81f9_e03f49dd8211row0_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_ff3704e8_8cb6_11ea_81f9_e03f49dd8211row0_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_ff3704e8_8cb6_11ea_81f9_e03f49dd8211row0_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_ff3704e8_8cb6_11ea_81f9_e03f49dd8211row0_col6 {
#             background-color:  #6384eb;
#             color:  #000000;
#         }    #T_ff3704e8_8cb6_11ea_81f9_e03f49dd8211row0_col7 {
#             background-color:  #6282ea;
#             color:  #000000;
#         }    #T_ff3704e8_8cb6_11ea_81f9_e03f49dd8211row0_col8 {
#             background-color:  #6e90f2;
#             color:  #000000;
#         }    #T_ff3704e8_8cb6_11ea_81f9_e03f49dd8211row0_col9 {
#             background-color:  #82a6fb;
#             color:  #000000;
#         }    #T_ff3704e8_8cb6_11ea_81f9_e03f49dd8211row0_col10 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_ff3704e8_8cb6_11ea_81f9_e03f49dd8211row0_col11 {
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }    #T_ff3704e8_8cb6_11ea_81f9_e03f49dd8211row0_col12 {
#             background-color:  #f0cdbb;
#             color:  #000000;
#         }    #T_ff3704e8_8cb6_11ea_81f9_e03f49dd8211row0_col13 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_ff3704e8_8cb6_11ea_81f9_e03f49dd8211row0_col14 {
#             background-color:  #c7d7f0;
#             color:  #000000;
#         }    #T_ff3704e8_8cb6_11ea_81f9_e03f49dd8211row0_col15 {
#             background-color:  #f7ad90;
#             color:  #000000;
#         }    #T_ff3704e8_8cb6_11ea_81f9_e03f49dd8211row0_col16 {
#             background-color:  #cdd9ec;
#             color:  #000000;
#         }    #T_ff3704e8_8cb6_11ea_81f9_e03f49dd8211row0_col17 {
#             background-color:  #9ebeff;
#             color:  #000000;
#         }    #T_ff3704e8_8cb6_11ea_81f9_e03f49dd8211row0_col18 {
#             background-color:  #98b9ff;
#             color:  #000000;
#         }    #T_ff3704e8_8cb6_11ea_81f9_e03f49dd8211row0_col19 {
#             background-color:  #f39475;
#             color:  #000000;
#         }    #T_ff3704e8_8cb6_11ea_81f9_e03f49dd8211row0_col20 {
#             background-color:  #d8dce2;
#             color:  #000000;
#         }    #T_ff3704e8_8cb6_11ea_81f9_e03f49dd8211row0_col21 {
#             background-color:  #a5c3fe;
#             color:  #000000;
#         }    #T_ff3704e8_8cb6_11ea_81f9_e03f49dd8211row0_col22 {
#             background-color:  #a5c3fe;
#             color:  #000000;
#         }    #T_ff3704e8_8cb6_11ea_81f9_e03f49dd8211row0_col23 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_ff3704e8_8cb6_11ea_81f9_e03f49dd8211row1_col0 {
#             background-color:  #f6a385;
#             color:  #000000;
#         }    #T_ff3704e8_8cb6_11ea_81f9_e03f49dd8211row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_ff3704e8_8cb6_11ea_81f9_e03f49dd8211row1_col2 {
#             background-color:  #f4c5ad;
#             color:  #000000;
#         }    #T_ff3704e8_8cb6_11ea_81f9_e03f49dd8211row1_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_ff3704e8_8cb6_11ea_81f9_e03f49dd8211row1_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_ff3704e8_8cb6_11ea_81f9_e03f49dd8211row1_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_ff3704e8_8cb6_11ea_81f9_e03f49dd8211row1_col6 {
#             background-color:  #bcd2f7;
#             color:  #000000;
#         }    #T_ff3704e8_8cb6_11ea_81f9_e03f49dd8211row1_col7 {
#             background-color:  #6282ea;
#             color:  #000000;
#         }    #T_ff3704e8_8cb6_11ea_81f9_e03f49dd8211row1_col8 {
#             background-color:  #7396f5;
#             color:  #000000;
#         }    #T_ff3704e8_8cb6_11ea_81f9_e03f49dd8211row1_col9 {
#             background-color:  #adc9fd;
#             color:  #000000;
#         }    #T_ff3704e8_8cb6_11ea_81f9_e03f49dd8211row1_col10 {
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }    #T_ff3704e8_8cb6_11ea_81f9_e03f49dd8211row1_col11 {
#             background-color:  #7295f4;
#             color:  #000000;
#         }    #T_ff3704e8_8cb6_11ea_81f9_e03f49dd8211row1_col12 {
#             background-color:  #f08b6e;
#             color:  #000000;
#         }    #T_ff3704e8_8cb6_11ea_81f9_e03f49dd8211row1_col13 {
#             background-color:  #5a78e4;
#             color:  #000000;
#         }    #T_ff3704e8_8cb6_11ea_81f9_e03f49dd8211row1_col14 {
#             background-color:  #f4c6af;
#             color:  #000000;
#         }    #T_ff3704e8_8cb6_11ea_81f9_e03f49dd8211row1_col15 {
#             background-color:  #f59f80;
#             color:  #000000;
#         }    #T_ff3704e8_8cb6_11ea_81f9_e03f49dd8211row1_col16 {
#             background-color:  #e2dad5;
#             color:  #000000;
#         }    #T_ff3704e8_8cb6_11ea_81f9_e03f49dd8211row1_col17 {
#             background-color:  #93b5fe;
#             color:  #000000;
#         }    #T_ff3704e8_8cb6_11ea_81f9_e03f49dd8211row1_col18 {
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }    #T_ff3704e8_8cb6_11ea_81f9_e03f49dd8211row1_col19 {
#             background-color:  #f7b396;
#             color:  #000000;
#         }    #T_ff3704e8_8cb6_11ea_81f9_e03f49dd8211row1_col20 {
#             background-color:  #f5c2aa;
#             color:  #000000;
#         }    #T_ff3704e8_8cb6_11ea_81f9_e03f49dd8211row1_col21 {
#             background-color:  #edd1c2;
#             color:  #000000;
#         }    #T_ff3704e8_8cb6_11ea_81f9_e03f49dd8211row1_col22 {
#             background-color:  #abc8fd;
#             color:  #000000;
#         }    #T_ff3704e8_8cb6_11ea_81f9_e03f49dd8211row1_col23 {
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }    #T_ff3704e8_8cb6_11ea_81f9_e03f49dd8211row2_col0 {
#             background-color:  #b50927;
#             color:  #f1f1f1;
#         }    #T_ff3704e8_8cb6_11ea_81f9_e03f49dd8211row2_col1 {
#             background-color:  #f4c6af;
#             color:  #000000;
#         }    #T_ff3704e8_8cb6_11ea_81f9_e03f49dd8211row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_ff3704e8_8cb6_11ea_81f9_e03f49dd8211row2_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_ff3704e8_8cb6_11ea_81f9_e03f49dd8211row2_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_ff3704e8_8cb6_11ea_81f9_e03f49dd8211row2_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_ff3704e8_8cb6_11ea_81f9_e03f49dd8211row2_col6 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_ff3704e8_8cb6_11ea_81f9_e03f49dd8211row2_col7 {
#             background-color:  #6282ea;
#             color:  #000000;
#         }    #T_ff3704e8_8cb6_11ea_81f9_e03f49dd8211row2_col8 {
#             background-color:  #6a8bef;
#             color:  #000000;
#         }    #T_ff3704e8_8cb6_11ea_81f9_e03f49dd8211row2_col9 {
#             background-color:  #7a9df8;
#             color:  #000000;
#         }    #T_ff3704e8_8cb6_11ea_81f9_e03f49dd8211row2_col10 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_ff3704e8_8cb6_11ea_81f9_e03f49dd8211row2_col11 {
#             background-color:  #3f53c6;

# %% [markdown]
# When reviewing the Pearson correlation coefficient heatmap, you can see substantial differences in the correlations compared to the response variable(s) as well as in the features when compared to each other. The heatmap helps identify features that suffer from multi-collinearity.

# %% [markdown]
# <font color='teal'>**Use the correlation matrix displayed in the heatmap to select and remove collinear features. Remember to exclude the response variable(s) from the matrix to ensure they are retained in your final model development dataset. Then select those features that are more than 95% correlated for removal.**</font>
#
# Step 1: Create a correlation matrix that excludes your response variables.
#
# Step 2: Select the upper triangle of the correlation matrix. This is because a correlation matrix actually contains the same information, twice over!
#
# Step 3: Find the index of feature columns with a correlation greater than 0.95.

# %%
# Step 1. Call the variable corr_matrix
corr_matrix = dfno.drop(['AdultWeekday','AdultWeekend','daysOpenLastYear','projectedDaysOpen'], axis=1).corr().abs()

# Step 2. Uncomment the following code to get the upper triangle of the correlation matrix 
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# Step 3. This code iterates through our columns and gets the index of any that have a correlation > 0.95
# Call the variable to_drop, get the columns of our 'upper' variable, make sure the threshold is 0.95.
to_drop = [column for column in corr_matrix.columns if any(upper[column] > 0.95)]

# %%
print(corr_matrix)
# Out:
#                    summit_elev  vertical_drop  base_elev  trams  fastEight  \
# summit_elev           1.000000       0.619149   0.986851    NaN        NaN
# vertical_drop         0.619149       1.000000   0.490793    NaN        NaN
# base_elev             0.986851       0.490793   1.000000    NaN        NaN
# trams                      NaN            NaN        NaN    NaN        NaN
# fastEight                  NaN            NaN        NaN    NaN        NaN
# fastSixes                  NaN            NaN        NaN    NaN        NaN
# fastQuads             0.148052       0.398271   0.084600    NaN        NaN
# quad                  0.050460       0.053086   0.054985    NaN        NaN
# triple                0.062269       0.077661   0.054588    NaN        NaN
# double                0.091510       0.233237   0.058666    NaN        NaN
# surface               0.379704       0.335937   0.352583    NaN        NaN
# total_chairs          0.102613       0.057817   0.124537    NaN        NaN
# Runs                  0.497281       0.738059   0.407433    NaN        NaN
# TerrainParks          0.036362       0.121492   0.017417    NaN        NaN
# LongestRun_mi         0.327275       0.561787   0.254606    NaN        NaN
# SkiableTerrain_ac     0.620178       0.671651   0.561062    NaN        NaN
# Snow Making_ac        0.346336       0.443994   0.300367    NaN        NaN
# yearsOpen             0.211919       0.257305   0.183456    NaN        NaN
# averageSnowfall       0.678066       0.571161   0.643995    NaN        NaN
# NightSkiing_ac        0.238483       0.176452   0.228409    NaN        NaN
#
#                    fastSixes  fastQuads      quad    triple    double  \
# summit_elev              NaN   0.148052  0.050460  0.062269  0.091510
# vertical_drop            NaN   0.398271  0.053086  0.077661  0.233237
# base_elev                NaN   0.084600  0.054985  0.054588  0.058666
# trams                    NaN        NaN       NaN       NaN       NaN
# fastEight                NaN        NaN       NaN       NaN       NaN
# fastSixes                NaN        NaN       NaN       NaN       NaN
# fastQuads                NaN   1.000000  0.136661  0.175558  0.139642
# quad                     NaN   0.136661  1.000000  0.162897  0.172607
# triple                   NaN   0.175558  0.162897  1.000000  0.124922
# double                   NaN   0.139642  0.172607  0.124922  1.000000
# surface                  NaN   0.055951  0.193714  0.108177  0.023096
# total_chairs             NaN   0.433081  0.364555  0.515730  0.466562
# Runs                     NaN   0.370085  0.068306  0.128319  0.339371
# TerrainParks             NaN   0.267054  0.121914  0.318320  0.321957
# LongestRun_mi            NaN   0.350203  0.015980  0.128894  0.181798
# SkiableTerrain_ac        NaN   0.193663  0.075683  0.030129  0.275480
# Snow Making_ac           NaN   0.386193  0.087986  0.233887  0.272077
# yearsOpen                NaN   0.020237  0.076549  0.031465  0.216422
# averageSnowfall          NaN   0.077724  0.195923  0.014783  0.153415
# NightSkiing_ac           NaN   0.144798  0.158647  0.275712  0.106733
#
#                     surface  total_chairs      Runs  TerrainParks  \
# summit_elev        0.379704      0.102613  0.497281      0.036362
# vertical_drop      0.335937      0.057817  0.738059      0.121492
# base_elev          0.352583      0.124537  0.407433      0.017417
# trams                   NaN           NaN       NaN           NaN
# fastEight               NaN           NaN       NaN           NaN
# fastSixes               NaN           NaN       NaN           NaN
# fastQuads          0.055951      0.433081  0.370085      0.267054
# quad               0.193714      0.364555  0.068306      0.121914
# triple             0.108177      0.515730  0.128319      0.318320
# double             0.023096      0.466562  0.339371      0.321957
# surface            1.000000      0.622600  0.210518      0.220387
# total_chairs       0.622600      1.000000  0.229671      0.523395
# Runs               0.210518      0.229671  1.000000      0.350693
# TerrainParks       0.220387      0.523395  0.350693      1.000000
# LongestRun_mi      0.158401      0.145039  0.591817      0.197349
# SkiableTerrain_ac  0.264814      0.020604  0.565648      0.139477
# Snow Making_ac     0.165460      0.272201  0.495066      0.298989
# yearsOpen          0.100236      0.036816  0.270160      0.072142
# averageSnowfall    0.352578      0.141078  0.447088      0.053035
# NightSkiing_ac     0.192429      0.354734  0.114787      0.335701
#
#                    LongestRun_mi  SkiableTerrain_ac  Snow Making_ac  \
# summit_elev             0.327275           0.620178        0.346336
# vertical_drop           0.561787           0.671651        0.443994
# base_elev               0.254606           0.561062        0.300367
# trams                        NaN                NaN             NaN
# fastEight                    NaN                NaN             NaN
# fastSixes                    NaN                NaN             NaN
# fastQuads               0.350203           0.193663        0.386193
# quad                    0.015980           0.075683        0.087986
# triple                  0.128894           0.030129        0.233887
# double                  0.181798           0.275480        0.272077
# surface                 0.158401           0.264814        0.165460
# total_chairs            0.145039           0.020604        0.272201
# Runs                    0.591817           0.565648        0.495066
# TerrainParks            0.197349           0.139477        0.298989
# LongestRun_mi           1.000000           0.388422        0.411624
# SkiableTerrain_ac       0.388422           1.000000        0.332729
# Snow Making_ac          0.411624           0.332729        1.000000
# yearsOpen               0.064456           0.178736        0.260390
# averageSnowfall         0.313163           0.565855        0.303499
# NightSkiing_ac          0.093236           0.127995        0.176687
#
#                    yearsOpen  averageSnowfall  NightSkiing_ac
# summit_elev         0.211919         0.678066        0.238483
# vertical_drop       0.257305         0.571161        0.176452
# base_elev           0.183456         0.643995        0.228409
# trams                    NaN              NaN             NaN
# fastEight                NaN              NaN             NaN
# fastSixes                NaN              NaN             NaN
# fastQuads           0.020237         0.077724        0.144798
# quad                0.076549         0.195923        0.158647
# triple              0.031465         0.014783        0.275712
# double              0.216422         0.153415        0.106733
# surface             0.100236         0.352578        0.192429
# total_chairs        0.036816         0.141078        0.354734
# Runs                0.270160         0.447088        0.114787
# TerrainParks        0.072142         0.053035        0.335701
# LongestRun_mi       0.064456         0.313163        0.093236
# SkiableTerrain_ac   0.178736         0.565855        0.127995
# Snow Making_ac      0.260390         0.303499        0.176687
# yearsOpen           1.000000         0.270206        0.041960
# averageSnowfall     0.270206         1.000000        0.178491
# NightSkiing_ac      0.041960         0.178491        1.000000

# %%
# Let's see those features! 
print('Features selected to drop include:',to_drop)
# Out:
# Features selected to drop include: ['base_elev']

# %%
print('Reduced dataframe size: ',dfno.drop(dfno[to_drop], axis=1).shape)
# Out:
# Reduced dataframe size:  (176, 25)

# %%
# Now replace dfno by the result of dropping the columns in the to_drop variable from it
dfno = dfno.drop(dfno[to_drop], axis=1)

# %% [markdown]
# Now we address the feature creation piece of this step. We can create additional features through many methods such as: combining several features, grouping features into bins, or even by applying an unsupervised classification algorithm, such as k-means clustering and using the clusters as features in our model development dataset.
#
# Clustering essentially finds patterns in data when we don't know in advance what we're looking for. The K-means algorithm is one way of doing clustering. It puts our data into groups (or 'clusters') which can then become features for further analysis. What the k-means algorithm outputs, though, depends on the number of clusters we set out to have. We will use a method called 'Elbow plotting' to determine this number.
#
# We will cover clustering and k-means thoroughly in the Unsupervised Learning unit of this course, but for now, we'll use it for feature creation alone, which is an integral part of Exploratory Data Analysis. Don't worry if you don't understand the details just yet.

# %% [markdown]
# Run the next two cells below to create an Elbow plot. The Elbow plot is a diagnostic tool that helps us determine the number of clusters to include in our k-means clustering implementation.
#
# In this example, the error between clusters and within clusters is compared for a range of 1 to 11 clusters, and it appears the elbow is between two and four, therefore we set the parameter k = 3.

# %%
from sklearn.cluster import KMeans
x = dfno.drop(['Name','state'], axis =1).values

# %%
Error =[]
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i).fit(x)
    kmeans.fit(x)
    Error.append(kmeans.inertia_)
import matplotlib.pyplot as plt
plt.plot(range(1, 11), Error)
plt.title('Elbow method')
plt.xlabel('No of clusters')
plt.ylabel('Error')
plt.show()

# %% [markdown]
# <font color='teal'>**Fit the kmeans algorithm with the k parameter set to three and plot the results.**</font>

# %%
# This code will fit the k-means algorithm with our k parameter set to three, and plot the results. Cool, huh? 
kmeans3 = KMeans(n_clusters=3)
y_kmeans3 = kmeans3.fit_predict(x)
plt.scatter(x[:, 0], x[:, 1], c=y_kmeans3, s=50, cmap='viridis')

centers = kmeans3.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5);

# %% [markdown]
# <font color='teal'>**Add the clusters to your dataframe as a new column to include in the next step and write the updated dataframe out as csv. Save the dataframe in the data folder and name it `step3_output.csv`.**</font>

# %%
# Make a new column in your dfno dataframe called 'clusters', and assign it the variable: y_kmeans3
dfno['cluster'] = y_kmeans3

# %%
# Write your dataframe to csv 
dfno.to_csv('data/step3_output.csv', index=False)
